# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/saro/Desktop/dvdrentaldl/dvd rental final csv.csv')

# %%
df.head()
# Out:
#    inventory_id  film_id            title  rental_duration  rental_rate  \
# 0          3419      749      Rules Human                6         4.99
# 1          2512      552  Majestic Floats                5         0.99
# 2          2507      551      Maiden Home                3         4.99
# 3          2047      445      Hyde Doctor                5         2.99
# 4          2569      563   Massacre Usual                6         4.99
#
#    length  replacement_cost rating     category              language  \
# 0     153             19.99      R       Horror  English
# 1     130             15.99     PG  Documentary  English
# 2     138              9.99     PG          New  English
# 3     100             11.99      G     Classics  English
# 4     165             16.99      R        Games  English
#
#    store_id  rental_id          rental_date  customer_id          return_date  \
# 0         1       1520  2005-06-15 23:57:20          341  2005-06-24 23:46:20
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# inventory_id        0
# film_id             0
# title               0
# rental_duration     0
# rental_rate         0
# length              0
# replacement_cost    0
# rating              0
# category            0
# language            0
# store_id            0
# rental_id           0
# rental_date         0
# customer_id         0
# return_date         0
# amount              0
# active              0
# dtype: int64

# %%
customer_rental = df.groupby('customer_id').size().sort_values(ascending=False)

plt.figure(figsize=(20,6))
customer_rental.head(80).plot(kind='bar',color='green',alpha=0.7)

# Adding title and labels
plt.title('Number of Rentals per Customer')
plt.xlabel('Customer ID')
plt.ylabel('Number of Rentals')

# Show the plot
plt.show()

# %%
rentals_per_day = df.resample('D', on='rental_date').size()

# Plotting the number of rentals over time
plt.figure(figsize=(10, 6))
plt.plot(rentals_per_day.index, rentals_per_day.values, color='green', alpha=0.7)

# Adding title and labels
plt.title('Number of Rentals Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Rentals')

# Show the plot
plt.show()

# %%
df.head()
# Out:
#    inventory_id  film_id            title  rental_duration  rental_rate  \
# 0          3419      749      Rules Human                6         4.99
# 1          2512      552  Majestic Floats                5         0.99
# 2          2507      551      Maiden Home                3         4.99
# 3          2047      445      Hyde Doctor                5         2.99
# 4          2569      563   Massacre Usual                6         4.99
#
#    length  replacement_cost rating     category              language  \
# 0     153             19.99      R       Horror  English
# 1     130             15.99     PG  Documentary  English
# 2     138              9.99     PG          New  English
# 3     100             11.99      G     Classics  English
# 4     165             16.99      R        Games  English
#
#    store_id  rental_id          rental_date  customer_id          return_date  \
# 0         1       1520  2005-06-15 23:57:20          341  2005-06-24 23:46:20
# ...

# %%
# 1. Rental Rates Distribution
plt.figure(figsize=(10, 6))
rental_rate_counts = df['rental_rate'].value_counts().sort_index()
rental_rate_counts.plot(kind='bar', color='skyblue', edgecolor='black')
# plt.hist(df['rental_rate'], color='skyblue', edgecolor='black')
plt.title('Distribution of Rental Rates')
plt.xlabel('Rental Rate')
plt.ylabel('Frequency')
plt.show()

# %%
# 2. Film Length Distribution
plt.figure(figsize=(10, 6))
plt.hist(df['length'], bins=20, color='lightgreen', edgecolor='black')
plt.title('Distribution of Film Length')
plt.xlabel('Film Length (minutes)')
plt.ylabel('Frequency')
plt.show()

# %%
# 3. Top Film Categories (Bar Plot)
category_counts = df['category'].value_counts()

plt.figure(figsize=(10, 6))
category_counts.plot(kind='bar', color='salmon', edgecolor='black')
plt.title('Top Film Categories')
plt.xlabel('Category')
plt.ylabel('Number of Films')
plt.xticks(rotation=45)
plt.show()

# %%
df.head()
# Out:
#    inventory_id  film_id            title  rental_duration  rental_rate  \
# 0          3419      749      Rules Human                6         4.99
# 1          2512      552  Majestic Floats                5         0.99
# 2          2507      551      Maiden Home                3         4.99
# 3          2047      445      Hyde Doctor                5         2.99
# 4          2569      563   Massacre Usual                6         4.99
#
#    length  replacement_cost rating     category              language  \
# 0     153             19.99      R       Horror  English
# 1     130             15.99     PG  Documentary  English
# 2     138              9.99     PG          New  English
# 3     100             11.99      G     Classics  English
# 4     165             16.99      R        Games  English
#
#    store_id  rental_id          rental_date  customer_id          return_date  \
# 0         1       1520  2005-06-15 23:57:20          341  2005-06-24 23:46:20
# ...

# %%
df.head()
# Out:
#    inventory_id  film_id            title  rental_duration  rental_rate  \
# 0          3419      749      Rules Human                6         4.99
# 1          2512      552  Majestic Floats                5         0.99
# 2          2507      551      Maiden Home                3         4.99
# 3          2047      445      Hyde Doctor                5         2.99
# 4          2569      563   Massacre Usual                6         4.99
#
#    length  replacement_cost rating     category              language  \
# 0     153             19.99      R       Horror  English
# 1     130             15.99     PG  Documentary  English
# 2     138              9.99     PG          New  English
# 3     100             11.99      G     Classics  English
# 4     165             16.99      R        Games  English
#
#    store_id  rental_id          rental_date  customer_id          return_date  \
# 0         1       1520  2005-06-15 23:57:20          341  2005-06-24 23:46:20
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your original DataFrame
df_continuous = df.select_dtypes(include=['number'])

# Compute correlation matrix
correlation_matrix = df_continuous.corr()

# Plot heatmap of the correlation matrix
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

# Show the heatmap
plt.show()

# %%
# rental duration is how many days the movie can be rented. this doesn't serve the purpose because it is not actual.

# %%
df.head()
# Out:
#    inventory_id  film_id            title  rental_duration  rental_rate  \
# 0          3419      749      Rules Human                6         4.99
# 1          2512      552  Majestic Floats                5         0.99
# 2          2507      551      Maiden Home                3         4.99
# 3          2047      445      Hyde Doctor                5         2.99
# 4          2569      563   Massacre Usual                6         4.99
#
#    length  replacement_cost rating     category              language  \
# 0     153             19.99      R       Horror  English
# 1     130             15.99     PG  Documentary  English
# 2     138              9.99     PG          New  English
# 3     100             11.99      G     Classics  English
# 4     165             16.99      R        Games  English
#
#    store_id  rental_id          rental_date  customer_id          return_date  \
# 0         1       1520  2005-06-15 23:57:20          341  2005-06-24 23:46:20
# ...

# %%
# Ensure the rental_date and return_date are in datetime format
df['rental_date'] = pd.to_datetime(df['rental_date'])
df['return_date'] = pd.to_datetime(df['return_date'])

# Calculate the difference in days between return_date and rental_date
df['rental_actual_duration'] = (df['return_date'] - df['rental_date']).dt.days

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your original DataFrame
df_continuous = df.select_dtypes(include=['number'])

# Compute correlation matrix
correlation_matrix = df_continuous.corr()

# Plot heatmap of the correlation matrix
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

# Show the heatmap
plt.show()

# %%
#rental actual duration is highly positively correlated with amount
# id relationship with other can be neglected after careful consideration
